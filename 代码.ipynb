# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from geneview.gwas import qqplot

# %%
#df=pd.read_excel('horse_data.xls',na_values=['nan'])
pd.set_option('max_columns',30)
df=pd.read_excel('horse_data.xls')
print df.describe()
# Out:
#           surgery         Age  Hospital Number   rectal temperature  \
# count  366.000000  368.000000      3.680000e+02          299.000000
# mean     1.415301    1.608696      1.112334e+06           38.134448
# std      0.493448    2.123985      1.560122e+06            0.711684
# min      1.000000    1.000000      5.142790e+05           35.400000
# 25%      1.000000    1.000000      5.289152e+05           37.800000
# 50%      1.000000    1.000000      5.302990e+05           38.100000
# 75%      2.000000    1.000000      5.347275e+05           38.500000
# max      2.000000    9.000000      5.305629e+06           40.800000
#
#             pulse  respiratory rate  temperature of extremities  \
# count  342.000000        297.000000                  303.000000
# mean    70.757310         30.521886                    2.356436
# std     28.089867         17.669651                    1.041371
# min     30.000000          8.000000                    1.000000
# ...

# %%
print df['respiratory rate'].value_counts()
# Out:
# 20.0    35
# 24.0    30
# 12.0    27
# 16.0    26
# 30.0    26
# 40.0    22
# 36.0    20
# 28.0    16
# 32.0    12
# 18.0    10
# 60.0    10
# 48.0     6
# 44.0     5
# 14.0     4
# 10.0     4
# 96.0     3
# 35.0     3
# 68.0     3
# 80.0     3
# 42.0     3
# 84.0     2
# 70.0     2
# 21.0     2
# 90.0     2
# 72.0     2
# 22.0     2
# 51.0     2
# 9.0      2
# 50.0     2
# 23.0     1
# 15.0     1
# 34.0     1
# 25.0     1
# 8.0      1
# 52.0     1
# 58.0     1
# 13.0     1
# 66.0     1
# 26.0     1
# 88.0     1
# Name: respiratory rate, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=368, step=1)

# %%
a=df['respiratory rate'].value_counts()
#print a
print a.keys()[0]
# Out:
# 20.0

# %%
print df['surgery'].value_counts()
# Out:
# 1.0    214
# 2.0    152
# Name: surgery, dtype: int64

# %%
print df['temperature of extremities'].value_counts()
# Out:
# 3.0    135
# 1.0     95
# 2.0     39
# 4.0     34
# Name: temperature of extremities, dtype: int64

# %%
print df['capillary refill time'].value_counts()
# Out:
# 1.0    232
# 2.0     96
# 3.0      2
# Name: capillary refill time, dtype: int64

# %%
print df['pain'].value_counts()
# Out:
# 3.0    82
# 2.0    77
# 5.0    50
# 1.0    49
# 4.0    47
# Name: pain, dtype: int64

# %%
print df['peristalsis'].value_counts()
# Out:
# 1.0    98
# 3.0    81
# 4.0    50
# 2.0    38
# 5.0    28
# 6.0    25
# Name: mucous membranes, dtype: int64

# %%
print df['abdominal distension'].value_counts()
# Out:
# 1.0    101
# 3.0     85
# 2.0     75
# 4.0     42
# Name: abdominal distension, dtype: int64

# %%
print df['nasogastric tube'].value_counts()
# Out:
# 2.0    121
# 1.0     89
# 3.0     27
# Name: nasogastric tube, dtype: int64

# %%
print df['nasogastric reflux'].value_counts()
# Out:
# 1.0    141
# 3.0     49
# 2.0     45
# Name: nasogastric reflux, dtype: int64

# %%
print df['rectal examination - feces'].value_counts()
# Out:
# 4.0    97
# 1.0    68
# 3.0    61
# 2.0    14
# Name: rectal examination - feces, dtype: int64

# %%
print df['abdomen'].value_counts()
# Out:
# 5.0    96
# 4.0    55
# 1.0    31
# 2.0    24
# 3.0    19
# Name: abdomen, dtype: int64

# %%
print df['abdominocentesis appearance'].value_counts()
# Out:
# 2.0    62
# 3.0    60
# 1.0    52
# Name: abdominocentesis appearance, dtype: int64

# %%
print df['outcome'].value_counts()
# Out:
# 1.0    225
# 2.0     89
# 3.0     52
# Name: outcome, dtype: int64

# %%
print df['surgical lesion'].value_counts()
# Out:
# 1    232
# 2    136
# Name: surgical lesion, dtype: int64

# %%
print df['cp_ data'].value_counts()
# Out:
# 2    244
# 1    124
# Name: cp_ data, dtype: int64

# %%
df.columns
# Out:
# Index([                    u'surgery',                         u'Age',
#                   u'Hospital Number ',          u'rectal temperature',
#                              u'pulse',            u'respiratory rate',
#         u'temperature of extremities',            u'peripheral pulse',
#                   u'mucous membranes',       u'capillary refill time',
#                               u'pain',                 u'peristalsis',
#               u'abdominal distension',            u'nasogastric tube',
#                 u'nasogastric reflux',       u'nasogastric reflux PH',
#         u'rectal examination - feces',                     u'abdomen',
#                u' packed cell volume',               u'total protein',
#        u'abdominocentesis appearance', u'abdomcentesis total protein',
#                            u'outcome',             u'surgical lesion',
#                    u' type of lesion',                 u'Unnamed: 25',
# ...

# %%
df.describe()['rectal temperature']
# Out:
# count    299.000000
# mean      38.134448
# std        0.711684
# min       35.400000
# 25%       37.800000
# 50%       38.100000
# 75%       38.500000
# max       40.800000
# Name: rectal temperature, dtype: float64

# %%
df.describe()['pulse']
# Out:
# count    342.000000
# mean      70.757310
# std       28.089867
# min       30.000000
# 25%       48.000000
# 50%       60.000000
# 75%       88.000000
# max      184.000000
# Name: pulse, dtype: float64

# %%
df.describe()['respiratory rate']
# Out:
# count    297.000000
# mean      30.521886
# std       17.669651
# min        8.000000
# 25%       18.000000
# 50%       28.000000
# 75%       36.000000
# max       96.000000
# Name: respiratory rate, dtype: float64

# %%
df.describe()['nasogastric reflux PH']
# Out:
# count    69.000000
# mean      4.962319
# std       2.003901
# min       1.000000
# 25%       3.500000
# 50%       5.400000
# 75%       6.500000
# max       8.500000
# Name: nasogastric reflux PH, dtype: float64

# %%
df.describe()[' packed cell volume']
# Out:
# count    331.000000
# mean      45.656798
# std       10.865663
# min        4.000000
# 25%       37.250000
# 50%       44.000000
# 75%       52.000000
# max       75.000000
# Name:  packed cell volume, dtype: float64

# %%
df.describe()['total protein']
# Out:
# count    325.000000
# mean      24.771077
# std       27.704880
# min        3.300000
# 25%        6.500000
# 50%        7.500000
# 75%       58.000000
# max       89.000000
# Name: total protein, dtype: float64

# %%
df.describe()['abdomcentesis total protein']
# Out:
# count    133.000000
# mean       2.948120
# std        1.927064
# min        0.100000
# 25%        2.000000
# 50%        2.100000
# 75%        3.900000
# max       10.100000
# Name: abdomcentesis total protein, dtype: float64

# %%
print df['rectal temperature'].value_counts()
# Out:
# 38.0    34
# 38.3    23
# 38.2    23
# 37.8    21
# 38.5    21
# 37.5    16
# 38.1    15
# 38.4    14
# 38.6    14
# 37.6    10
# 37.7    10
# 37.9     9
# 38.7     9
# 37.2     7
# 37.3     6
# 39.0     6
# 38.8     6
# 39.2     5
# 37.1     5
# 37.0     4
# 39.3     4
# 39.5     4
# 38.9     4
# 37.4     4
# 39.1     3
# 39.4     3
# 36.5     2
# 36.0     2
# 39.7     2
# 36.6     2
# 40.3     2
# 39.9     1
# 35.4     1
# 40.0     1
# 36.9     1
# 39.6     1
# 36.4     1
# 36.8     1
# 40.8     1
# 36.1     1
# Name: rectal temperature, dtype: int64

# %%
print df['pulse'].value_counts()
# Out:
# 48.0     35
# 60.0     33
# 40.0     21
# 44.0     16
# 88.0     15
# 42.0     15
# 52.0     14
# 72.0     13
# 100.0    13
# 120.0    12
# 84.0     11
# 80.0     11
# 54.0      9
# 56.0      9
# 96.0      8
# 64.0      8
# 66.0      7
# 50.0      6
# 104.0     5
# 68.0      5
# 92.0      5
# 76.0      5
# 78.0      5
# 70.0      4
# 45.0      4
# 90.0      4
# 36.0      4
# 150.0     3
# 86.0      3
# 112.0     3
# 108.0     3
# 114.0     3
# 140.0     3
# 30.0      2
# 82.0      2
# 65.0      2
# 130.0     2
# 75.0      2
# 124.0     2
# 164.0     1
# 98.0      1
# 184.0     1
# 38.0      1
# 49.0      1
# 146.0     1
# 160.0     1
# 132.0     1
# 46.0      1
# 129.0     1
# 128.0     1
# 55.0      1
# 110.0     1
# 136.0     1
# 34.0      1
# Name: pulse, dtype: int64

# %%
print df['respiratory rate'].value_counts()
# Out:
# 20.0    35
# 24.0    30
# 12.0    27
# 16.0    26
# 30.0    26
# 40.0    22
# 36.0    20
# 28.0    16
# 32.0    12
# 18.0    10
# 60.0    10
# 48.0     6
# 44.0     5
# 14.0     4
# 10.0     4
# 96.0     3
# 35.0     3
# 68.0     3
# 80.0     3
# 42.0     3
# 84.0     2
# 70.0     2
# 21.0     2
# 90.0     2
# 72.0     2
# 22.0     2
# 51.0     2
# 9.0      2
# 50.0     2
# 23.0     1
# 15.0     1
# 34.0     1
# 25.0     1
# 8.0      1
# 52.0     1
# 58.0     1
# 13.0     1
# 66.0     1
# 26.0     1
# 88.0     1
# Name: respiratory rate, dtype: int64

# %%
print df['nasogastric reflux PH'].value_counts()
# Out:
# 2.0    10
# 7.0     9
# 5.0     7
# 6.5     6
# 5.5     4
# 6.0     4
# 3.0     3
# 4.5     3
# 4.0     3
# 7.5     3
# 1.5     2
# 1.0     2
# 7.2     2
# 8.5     1
# 3.5     1
# 5.3     1
# 8.0     1
# 4.3     1
# 5.8     1
# 6.2     1
# 4.4     1
# 5.4     1
# 5.9     1
# 5.7     1
# Name: nasogastric reflux PH, dtype: int64

# %%
print df[' packed cell volume'].value_counts()
# Out:
# 37.0    22
# 45.0    17
# 44.0    17
# 43.0    17
# 50.0    16
# 35.0    16
# 40.0    14
# 36.0    13
# 47.0    13
# 48.0    11
# 42.0    11
# 33.0    10
# 38.0    10
# 41.0    10
# 39.0     9
# 60.0     9
# 46.0     9
# 54.0     8
# 52.0     7
# 49.0     7
# 55.0     6
# 57.0     6
# 65.0     6
# 53.0     6
# 64.0     5
# 34.0     5
# 68.0     4
# 59.0     4
# 32.0     4
# 30.0     3
# 58.0     3
# 66.0     3
# 73.0     2
# 74.0     2
# 51.0     2
# 31.0     2
# 56.0     2
# 63.0     2
# 75.0     2
# 69.0     2
# 31.5     1
# 4.0      1
# 62.0     1
# 28.0     1
# 37.5     1
# 72.0     1
# 71.0     1
# 67.0     1
# 26.0     1
# 24.0     1
# 27.0     1
# 23.0     1
# 70.0     1
# 6.4      1
# Name:  packed cell volume, dtype: int64

# %%
print df['total protein'].value_counts()
# Out:
# 7.5     17
# 6.5     16
# 7.0     15
# 6.6     12
# 6.0     11
# 5.9     10
# 65.0    10
# 6.8      9
# 7.2      9
# 6.7      9
# 6.2      8
# 8.5      7
# 70.0     7
# 6.3      7
# 6.4      6
# 5.8      6
# 8.0      6
# 6.1      6
# 75.0     5
# 7.7      5
# 5.7      5
# 64.0     5
# 56.0     5
# 7.6      5
# 69.0     5
# 7.8      4
# 61.0     4
# 67.0     4
# 8.6      4
# 5.5      4
#         ..
# 8.7      2
# 8.2      2
# 7.1      2
# 81.0     2
# 4.9      2
# 82.0     1
# 8.8      1
# 11.0     1
# 86.0     1
# 46.0     1
# 7.9      1
# 9.1      1
# 3.3      1
# 4.6      1
# 10.2     1
# 4.7      1
# 79.0     1
# 36.0     1
# 3.5      1
# 5.0      1
# 9.0      1
# 13.0     1
# 50.0     1
# 8.9      1
# 4.0      1
# 51.0     1
# 89.0     1
# 59.0     1
# 53.0     1
# 85.0     1
# Name: total protein, dtype: int64

# %%
print df['abdomcentesis total protein'].value_counts()
# Out:
# 2.0     33
# 1.0     21
# 3.9      5
# 5.0      4
# 2.8      4
# 2.6      4
# 3.6      3
# 4.3      3
# 3.4      3
# 7.0      3
# 1.4      3
# 1.1      2
# 2.5      2
# 2.1      2
# 8.0      2
# 3.1      2
# 2.2      2
# 4.5      2
# 2.3      2
# 5.3      2
# 3.0      2
# 4.6      2
# 1.6      2
# 6.0      2
# 4.1      2
# 1.5      1
# 10.0     1
# 6.5      1
# 0.9      1
# 4.4      1
# 2.9      1
# 1.3      1
# 4.8      1
# 5.2      1
# 5.7      1
# 6.6      1
# 3.3      1
# 7.4      1
# 0.1      1
# 4.7      1
# 3.7      1
# 10.1     1
# 3.2      1
# 1.8      1
# Name: abdomcentesis total protein, dtype: int64

# %%
df.fillna({3:38.0,4:48,5:20.0,15:2.0,18:37.0,19:7.5,21:2.0},inplace=True)
# Out:
#      surgery  Age  Hospital Number   rectal temperature  pulse  \
# 0        2.0    1            530101                38.5   66.0
# 1        1.0    1            534817                39.2   88.0
# 2        2.0    1            530334                38.3   40.0
# 3        1.0    9           5290409                39.1  164.0
# 4        2.0    1            530255                37.3  104.0
# 5        2.0    1            528355                 NaN    NaN
# 6        1.0    1            526802                37.9   48.0
# 7        1.0    1            529607                 NaN   60.0
# 8        2.0    1            530051                 NaN   80.0
# 9        2.0    9           5299629                38.3   90.0
# 10       1.0    1            528548                38.1   66.0
# 11       2.0    1            527927                39.1   72.0
# 12       1.0    1            528031                37.2   42.0
# 13       2.0    9           5291329                38.0   92.0
# ...

# %%
df.columns
# Out:
# Index([                    u'surgery',                         u'Age',
#                   u'Hospital Number ',          u'rectal temperature',
#                              u'pulse',            u'respiratory rate',
#         u'temperature of extremities',            u'peripheral pulse',
#                   u'mucous membranes',       u'capillary refill time',
#                               u'pain',                 u'peristalsis',
#               u'abdominal distension',            u'nasogastric tube',
#                 u'nasogastric reflux',       u'nasogastric reflux PH',
#         u'rectal examination - feces',                     u'abdomen',
#                u' packed cell volume',               u'total protein',
#        u'abdominocentesis appearance', u'abdomcentesis total protein',
#                            u'outcome',             u'surgical lesion',
#                    u' type of lesion',                 u'Unnamed: 25',
# ...

# %%
df['rectal temperature'].fillna(38.0, inplace=True)

# %%
df['pulse'].fillna(48, inplace=True)
df['respiratory rate'].fillna(20.0, inplace=True)
df['nasogastric reflux PH'].fillna(2.0, inplace=True)
df[' packed cell volume'].fillna(37.0, inplace=True)
df['total protein'].fillna(7.5, inplace=True)
df['abdomcentesis total protein'].fillna(2.0, inplace=True)

# %%
df.describe()
# Out:
#           surgery         Age  Hospital Number   rectal temperature  \
# count  366.000000  368.000000      3.680000e+02          368.000000
# mean     1.415301    1.608696      1.112334e+06           38.109239
# std      0.493448    2.123985      1.560122e+06            0.643451
# min      1.000000    1.000000      5.142790e+05           35.400000
# 25%      1.000000    1.000000      5.289152e+05           37.800000
# 50%      1.000000    1.000000      5.302990e+05           38.000000
# 75%      2.000000    1.000000      5.347275e+05           38.400000
# max      2.000000    9.000000      5.305629e+06           40.800000
#
#             pulse  respiratory rate  temperature of extremities  \
# count  368.000000        368.000000                  303.000000
# mean    69.149457         28.491848                    2.356436
# std     27.699083         16.404291                    1.041371
# min     30.000000          8.000000                    1.000000
# ...

# %%
df.to_excel('newmax.xlsx',sheet_name='Sheet_1')
